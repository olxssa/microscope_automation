# %% [markdown]
# # pymmcore-plus
#
# ##### internship on microscope automation
#
# Contact: Olyssa Sperling (olyssa.sperling@gmx.de) <br/>
# Supervisors: Andrew Plested & Thomas Korte <br/>
# Field of study: Biophysics <br/>
#
# Outline:
# 1. device properties & config groups
# 2. image acquisition: snap images, define and run acquistion sequences, define grid_plan
# 3. software autofocus
# 4. stitching of multi-tile images
# 5. multi-well scan
# 6. plate calibration

# %%
import os
import time
from useq import MDAEvent, MDASequence, Position
from pymmcore_plus.mda import mda_listeners_connected
from pymmcore_plus.mda.handlers import ImageSequenceWriter
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import numpy as np
from scipy.optimize import curve_fit
import glob
import pandas as pd
import m2stitch
from os import path

# set micro manager directory
mm_dir = 'D:\ProgramFiles\Micro-Manager-2.0'

# load micro manager system configuration
from pymmcore_plus import CMMCorePlus, Device, DeviceAdapter, ConfigGroup
core = CMMCorePlus()
#core_plus.setDeviceAdapterSearchPaths([mm_dir])
core.loadSystemConfiguration(os.path.join(mm_dir, 'MMConfig_Edge42_SOLA_ASIStage_PixelSize.cfg'))

# %%
# set field of view size
f = 1192.8

# %% [markdown]
# ### 1. device properties & config groups

# %% [markdown]
# ##### device properties

# %%
# camera

core.getCameraDevice()
device = Device('pco_camera', core)
device.properties
# Out:
# (<Property 'pco_camera::Acquiremode' on CMMCorePlus at 0x1f1c511b090: value='Internal'>,
#  <Property 'pco_camera::Binning' on CMMCorePlus at 0x1f1c511b090: value=1>,
#  <Property 'pco_camera::CCDType' on CMMCorePlus at 0x1f1c511b090: value='max X 2048 - max Y 2048'>,
#  <Property 'pco_camera::CameraType' on CMMCorePlus at 0x1f1c511b090: value='pco.edge 4.2 M CLHS rolling shutter - SN:3A2EBCB / Interface: CLHS'>,
#  <Property 'pco_camera::DemoMode' on CMMCorePlus at 0x1f1c511b090: value='Off'>,
#  <Property 'pco_camera::Description' on CMMCorePlus at 0x1f1c511b090: value='pco.sdk driver module'>,
#  <Property 'pco_camera::DotPhoton Filter' on CMMCorePlus at 0x1f1c511b090: value='Off'>,
#  <Property 'pco_camera::Exposure' on CMMCorePlus at 0x1f1c511b090: value=199.0>,
#  <Property 'pco_camera::Fan/LED: Automatic Fan Control' on CMMCorePlus at 0x1f1c511b090: value='On'>,
#  <Property 'pco_camera::Fan/LED: Camera LED' on CMMCorePlus at 0x1f1c511b090: value='On'>,
#  <Property 'pco_camera::Fan/LED: Fan Speed [%]' on CMMCorePlus at 0x1f1c511b090: value=60>,
#  <Property 'pco_camera::Line Time [us]' on CMMCorePlus at 0x1f1c511b090: value='26.58'>,
#  <Property 'pco_camera::Name' on CMMCorePlus at 0x1f1c511b090: value='pco camera'>,
#  <Property 'pco_camera::Noisefilter' on CMMCorePlus at 0x1f1c511b090: value='On'>,
#  <Property 'pco_camera::PixelRate' on CMMCorePlus at 0x1f1c511b090: value='slow scan'>,
#  <Property 'pco_camera::PixelType' on CMMCorePlus at 0x1f1c511b090: value='16bit'>,
#  <Property 'pco_camera::Signal 1 (Exposure Trigger) Polarity' on CMMCorePlus at 0x1f1c511b090: value='rising'>,
#  <Property 'pco_camera::Signal 1 (Exposure Trigger) Status' on CMMCorePlus at 0x1f1c511b090: value='on'>,
#  <Property 'pco_camera::Signal 2 (Acquire Enable) Polarity' on CMMCorePlus at 0x1f1c511b090: value='high'>,
#  <Property 'pco_camera::Signal 2 (Acquire Enable) Status' on CMMCorePlus at 0x1f1c511b090: value='on'>,
#  <Property 'pco_camera::Signal 3 (Status Busy) Polarity' on CMMCorePlus at 0x1f1c511b090: value='high'>,
#  <Property 'pco_camera::Signal 3 (Status Busy) Selection' on CMMCorePlus at 0x1f1c511b090: value='Status Busy'>,
#  <Property 'pco_camera::Signal 3 (Status Busy) Status' on CMMCorePlus at 0x1f1c511b090: value='on'>,
#  <Property 'pco_camera::Signal 3 (Status Busy) Timing' on CMMCorePlus at 0x1f1c511b090: value='Not available'>,
#  <Property 'pco_camera::Signal 4 (Status Exposure) Polarity' on CMMCorePlus at 0x1f1c511b090: value='high'>,
#  <Property 'pco_camera::Signal 4 (Status Exposure) Selection' on CMMCorePlus at 0x1f1c511b090: value='Status Exposure'>,
#  <Property 'pco_camera::Signal 4 (Status Exposure) Status' on CMMCorePlus at 0x1f1c511b090: value='on'>,
#  <Property 'pco_camera::Signal 4 (Status Exposure) Timing' on CMMCorePlus at 0x1f1c511b090: value="Show time of 'First Line'">,
#  <Property 'pco_camera::Signal 5 (CLHS Trigger) Status' on CMMCorePlus at 0x1f1c511b090: value='on'>,
#  <Property 'pco_camera::Timestampmode' on CMMCorePlus at 0x1f1c511b090: value='No stamp'>,
#  <Property 'pco_camera::TransposeCorrection' on CMMCorePlus at 0x1f1c511b090: value=0>,
#  <Property 'pco_camera::TransposeMirrorX' on CMMCorePlus at 0x1f1c511b090: value=0>,
#  <Property 'pco_camera::TransposeMirrorY' on CMMCorePlus at 0x1f1c511b090: value=0>,
#  <Property 'pco_camera::TransposeXY' on CMMCorePlus at 0x1f1c511b090: value=0>,
#  <Property 'pco_camera::Triggermode' on CMMCorePlus at 0x1f1c511b090: value='Internal'>)

# %%
# xy stage

core.getXYStageDevice()
device = Device('XYStage', core)
device.properties
# Out:
# (<Property 'XYStage::Acceleration-AC(ms)' on CMMCorePlus at 0x1c0f669fae0: value=100>,
#  <Property 'XYStage::AxisLetterX' on CMMCorePlus at 0x1c0f669fae0: value='X'>,
#  <Property 'XYStage::AxisLetterY' on CMMCorePlus at 0x1c0f669fae0: value='Y'>,
#  <Property 'XYStage::Backlash-B' on CMMCorePlus at 0x1c0f669fae0: value=0.04>,
#  <Property 'XYStage::BuildName' on CMMCorePlus at 0x1c0f669fae0: value='A2XYZ'>,
#  <Property 'XYStage::CompileDate' on CMMCorePlus at 0x1c0f669fae0: value='Apr 07 2017:12:26:13'>,
#  <Property 'XYStage::Description' on CMMCorePlus at 0x1c0f669fae0: value='ASI XY stage driver adapter'>,
#  <Property 'XYStage::EnableAdvancedProperties' on CMMCorePlus at 0x1c0f669fae0: value='No'>,
#  <Property 'XYStage::Error-E(nm)' on CMMCorePlus at 0x1c0f669fae0: value=400.0>,
#  <Property 'XYStage::FinishError-PCROS(nm)' on CMMCorePlus at 0x1c0f669fae0: value=24.0>,
#  <Property 'XYStage::JoyStick Fast Speed' on CMMCorePlus at 0x1c0f669fae0: value=60>,
#  <Property 'XYStage::JoyStick Reverse' on CMMCorePlus at 0x1c0f669fae0: value='Off'>,
#  <Property 'XYStage::JoyStick Slow Speed' on CMMCorePlus at 0x1c0f669fae0: value=5>,
#  <Property 'XYStage::Maximum Speed (Do Not Change)' on CMMCorePlus at 0x1c0f669fae0: value=8.576>,
#  <Property 'XYStage::MotorOnOff' on CMMCorePlus at 0x1c0f669fae0: value='On'>,
#  <Property 'XYStage::Name' on CMMCorePlus at 0x1c0f669fae0: value='XYStage'>,
#  <Property 'XYStage::OnlySendSerialCommandOnChange' on CMMCorePlus at 0x1c0f669fae0: value='Yes'>,
#  <Property 'XYStage::OverShoot(um)' on CMMCorePlus at 0x1c0f669fae0: value=0.0>,
#  <Property 'XYStage::Port' on CMMCorePlus at 0x1c0f669fae0: value='COM3'>,
#  <Property 'XYStage::SerialCommand' on CMMCorePlus at 0x1c0f669fae0: value=''>,
#  <Property 'XYStage::SerialResponse' on CMMCorePlus at 0x1c0f669fae0: value=''>,
#  <Property 'XYStage::Speed-S' on CMMCorePlus at 0x1c0f669fae0: value=5.7459>,
#  <Property 'XYStage::StepSizeX_um' on CMMCorePlus at 0x1c0f669fae0: value=0.01>,
#  <Property 'XYStage::StepSizeY_um' on CMMCorePlus at 0x1c0f669fae0: value=0.01>,
#  <Property 'XYStage::TransposeMirrorX' on CMMCorePlus at 0x1c0f669fae0: value=0>,
#  <Property 'XYStage::TransposeMirrorY' on CMMCorePlus at 0x1c0f669fae0: value=0>,
#  <Property 'XYStage::VectorMoveX-VE(mm/s)' on CMMCorePlus at 0x1c0f669fae0: value=0.0>,
#  <Property 'XYStage::VectorMoveY-VE(mm/s)' on CMMCorePlus at 0x1c0f669fae0: value=0.0>,
#  <Property 'XYStage::Version' on CMMCorePlus at 0x1c0f669fae0: value='Version: USB-9.2k '>,
#  <Property 'XYStage::Wait_Cycles' on CMMCorePlus at 0x1c0f669fae0: value=0>)

# %%
# focus

core.getFocusDevice()
device = Device('ZStage', core)
device.properties
# Out:
# (<Property 'ZStage::Acceleration-AC(ms)' on CMMCorePlus at 0x230c9ee1ae0: value=70>,
#  <Property 'ZStage::Axis' on CMMCorePlus at 0x230c9ee1ae0: value='Z'>,
#  <Property 'ZStage::Backlash-B' on CMMCorePlus at 0x230c9ee1ae0: value=0.01>,
#  <Property 'ZStage::BuildName' on CMMCorePlus at 0x230c9ee1ae0: value='A2XYZ'>,
#  <Property 'ZStage::CompileDate' on CMMCorePlus at 0x230c9ee1ae0: value='Apr 07 2017:12:26:13'>,
#  <Property 'ZStage::Description' on CMMCorePlus at 0x230c9ee1ae0: value='ASI Z-stage driver adapter'>,
#  <Property 'ZStage::Error-E(nm)' on CMMCorePlus at 0x230c9ee1ae0: value=200.0>,
#  <Property 'ZStage::FinishError-PCROS(nm)' on CMMCorePlus at 0x230c9ee1ae0: value=6.0>,
#  <Property 'ZStage::LinearSequenceResetTimeout(ms)' on CMMCorePlus at 0x230c9ee1ae0: value=10000.0>,
#  <Property 'ZStage::Maximum Speed (Do Not Change)' on CMMCorePlus at 0x230c9ee1ae0: value=1.92>,
#  <Property 'ZStage::MotorOnOff' on CMMCorePlus at 0x230c9ee1ae0: value='On'>,
#  <Property 'ZStage::Name' on CMMCorePlus at 0x230c9ee1ae0: value='ZStage'>,
#  <Property 'ZStage::OverShoot(um)' on CMMCorePlus at 0x230c9ee1ae0: value=0.0>,
#  <Property 'ZStage::Port' on CMMCorePlus at 0x230c9ee1ae0: value='COM3'>,
#  <Property 'ZStage::RingBufferSize' on CMMCorePlus at 0x230c9ee1ae0: value='50'>,
#  <Property 'ZStage::Speed-S' on CMMCorePlus at 0x230c9ee1ae0: value=1.2864>,
#  <Property 'ZStage::Use Fast Sequence' on CMMCorePlus at 0x230c9ee1ae0: value='No'>,
#  <Property 'ZStage::Use Sequence' on CMMCorePlus at 0x230c9ee1ae0: value='No'>,
#  <Property 'ZStage::VectorMove-VE(mm/s)' on CMMCorePlus at 0x230c9ee1ae0: value=0.0>,
#  <Property 'ZStage::Version' on CMMCorePlus at 0x230c9ee1ae0: value='Version: USB-9.2k '>,
#  <Property 'ZStage::Wait_Cycles' on CMMCorePlus at 0x230c9ee1ae0: value=0>)

# %%
core.setFocusDevice('ZStage')
core.initializeDevice('ZStage')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 core.setFocusDevice('ZStage')
# ----> 2 core.initializeDevice('ZStage')
#
# RuntimeError: Device already initialized (or initialization already attempted)

# %%
# fluorescence light source

device = Device('LightEngine', core)
device.properties
# Out:
# (<Property 'LightEngine::Connection' on CMMCorePlus at 0x1c0f669fae0: value='COM4'>,
#  <Property 'LightEngine::Description' on CMMCorePlus at 0x1c0f669fae0: value='Lumencor Light Engine'>,
#  <Property 'LightEngine::LEModel' on CMMCorePlus at 0x1c0f669fae0: value='SOLASE'>,
#  <Property 'LightEngine::Model' on CMMCorePlus at 0x1c0f669fae0: value='SOLASE'>,
#  <Property 'LightEngine::Name' on CMMCorePlus at 0x1c0f669fae0: value='LightEngine'>,
#  <Property 'LightEngine::State' on CMMCorePlus at 0x1c0f669fae0: value=0>,
#  <Property 'LightEngine::WHITE' on CMMCorePlus at 0x1c0f669fae0: value=0>,
#  <Property 'LightEngine::WHITE_Intensity' on CMMCorePlus at 0x1c0f669fae0: value=0>)

# %% [markdown]
# ##### config groups

# %%
core.getConfigGroupObject('LED_light')
# Out:
# ConfigGroup(presets=['off', 'on'], n_properties=1)

# %%
core.getConfigGroupObject('fluorescence')
# Out:
# ConfigGroup(presets=['off', 'on_50P', 'on_70P'], n_properties=3)

# %% [markdown]
# ### 5. multi-well scan

# %%
z = -1867.7

six_well_pos = [(20000, 40000, z), # A1
                (20000, 0, z), # A2
                (20000, -40000, z), # A3
                (-20000, 40000, z), # B1
                (-20000, 0, z), # B2
                (-20000, -40000, z) # B3
                ]

writer = ImageSequenceWriter(r'C:\Users\Admin\Desktop\focus', extension=".png", overwrite=True)

# %%
core.setRelativeXYPosition(0, 80000)

# %%
sequence = MDASequence(
    #axis_order = "tpgcz",
    stage_positions = [six_well_pos[0]],
    grid_plan = {'rows': 4, 'columns': 4, 
                 'relative_to': 'center',
                 'overlap': 20,
                 'mode': 'row_wise',
                 'fov_width': f,
                 'fov_height': f},
    channels = [{'group': 'LED_light', 'config': 'on'}]
)

# %%
with mda_listeners_connected(writer):
    core.mda.run(sequence)
    
core.snapImage()
im = core.getImage()

core.setConfig('LED_light', 'off')

plt.imshow(im, cmap='gray')
# Out:
# 2024-08-14 17:08:24,545 - pymmcore-plus - INFO - (_runner.py:321) MDA Started: stage_positions=(Position(x=20000.0, y=40000.0, z=-1867.7, name=None, sequence=None),) grid_plan=GridRowsColumns(fov_width=1192.7552, fov_height=1192.7552, overlap=(20.0, 20.0), mode=<OrderMode.row_wise: 'row_wise'>, rows=4, columns=4, relative_to=<RelativeTo.center: 'center'>) channels=(Channel(config='on', group='LED_light', exposure=None, do_stack=True, z_offset=0.0, acquire_every=1, camera=None),)
# 2024-08-14 17:08:24,549 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 0, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=18568.693760000002 y_pos=41431.30624 z_pos=-1867.7
# 2024-08-14 17:08:25,582 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 1, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=19522.89792 y_pos=41431.30624 z_pos=-1867.7
# 2024-08-14 17:08:26,398 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 2, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=20477.10208 y_pos=41431.30624 z_pos=-1867.7
# 2024-08-14 17:08:27,143 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 3, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=21431.306239999998 y_pos=41431.30624 z_pos=-1867.7
# 2024-08-14 17:08:28,006 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 4, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=18568.693760000002 y_pos=40477.10208 z_pos=-1867.7
# 2024-08-14 17:08:29,174 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 5, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=19522.89792 y_pos=40477.10208 z_pos=-1867.7
# 2024-08-14 17:08:30,012 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 6, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=20477.10208 y_pos=40477.10208 z_pos=-1867.7
# 2024-08-14 17:08:30,731 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 7, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=21431.306239999998 y_pos=40477.10208 z_pos=-1867.7
# 2024-08-14 17:08:31,605 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 8, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=18568.693760000002 y_pos=39522.89792 z_pos=-1867.7
# 2024-08-14 17:08:32,781 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 9, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=19522.89792 y_pos=39522.89792 z_pos=-1867.7
# 2024-08-14 17:08:33,602 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 10, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=20477.10208 y_pos=39522.89792 z_pos=-1867.7
# 2024-08-14 17:08:34,328 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 11, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=21431.306239999998 y_pos=39522.89792 z_pos=-1867.7
# 2024-08-14 17:08:35,172 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 12, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=18568.693760000002 y_pos=38568.69376 z_pos=-1867.7
# 2024-08-14 17:08:36,383 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 13, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=19522.89792 y_pos=38568.69376 z_pos=-1867.7
# 2024-08-14 17:08:37,190 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 14, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=20477.10208 y_pos=38568.69376 z_pos=-1867.7
# 2024-08-14 17:08:37,899 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'g': 15, 'c': 0}) channel=Channel(config='on', group='LED_light') x_pos=21431.306239999998 y_pos=38568.69376 z_pos=-1867.7
# 2024-08-14 17:08:38,763 - pymmcore-plus - INFO - (_runner.py:408) MDA Finished: stage_positions=(Position(x=20000.0, y=40000.0, z=-1867.7, name=None, sequence=None),) grid_plan=GridRowsColumns(fov_width=1192.7552, fov_height=1192.7552, overlap=(20.0, 20.0), mode=<OrderMode.row_wise: 'row_wise'>, rows=4, columns=4, relative_to=<RelativeTo.center: 'center'>) channels=(Channel(config='on', group='LED_light', exposure=None, do_stack=True, z_offset=0.0, acquire_every=1, camera=None),)

# %%
cross_images = glob.glob(r'C:\Users\Admin\Desktop\focus\*.png')
len(cross_images)
# Out:
# 16

# %%
images = np.stack([cv2.imread(file) for file in cross_images],
                  axis=0)
images_squeezed = images[:, :, :, 1]
images_squeezed.shape
# Out:
# (16, 2048, 2048)

# %%
result_df, _ = m2stitch.stitch_images(
    images_squeezed, r, c, 
    row_col_transpose=False,
    ncc_threshold=0.0001
)
# Out:
# 100%|██████████| 16/16 [01:26<00:00,  5.40s/it]
# 100%|██████████| 16/16 [01:25<00:00,  5.33s/it]
# 100%|██████████| 16/16 [00:58<00:00,  3.63s/it]
# 100%|██████████| 16/16 [00:07<00:00,  2.20it/s]

# %%
images = images_squeezed

# stitching example
result_df["y_pos2"] = result_df["y_pos"] - result_df["y_pos"].min()
result_df["x_pos2"] = result_df["x_pos"] - result_df["x_pos"].min()

size_y = images.shape[1]
size_x = images.shape[2]

stitched_image_size = (
    result_df["y_pos2"].max() + size_y,
    result_df["x_pos2"].max() + size_x,
)
stitched_image = np.zeros_like(images, shape=stitched_image_size)
for i, row in result_df.iterrows():
    stitched_image[
        row["y_pos2"] : row["y_pos2"] + size_y,
        row["x_pos2"] : row["x_pos2"] + size_x,
    ] = images[i]

# %%
plt.imshow(stitched_image, cmap='grey')

# %% [markdown]
# ### 6. plate calibration
