# %% [markdown]
# # 3. software autofocus

# %%
import os
import time
from useq import MDAEvent, MDASequence, Position
from pymmcore_plus.mda import mda_listeners_connected
from pymmcore_plus.mda.handlers import ImageSequenceWriter
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import numpy as np
from scipy.optimize import curve_fit
import glob
import pandas as pd
import m2stitch
from os import path

# set micro manager directory
mm_dir = 'D:\ProgramFiles\Micro-Manager-2.0'

# load micro manager system configuration
from pymmcore_plus import CMMCorePlus, Device, DeviceAdapter, ConfigGroup
core = CMMCorePlus()
#core_plus.setDeviceAdapterSearchPaths([mm_dir])
core.loadSystemConfiguration(os.path.join(mm_dir, 'MMConfig_Edge42_SOLA_ASIStage_PixelSize.cfg'))

# %%
# set field of view size
f = 1192.8

# %%
# acquire z-stack

z = -928
range = 20
step_size = 2

writer = ImageSequenceWriter(r'C:\Users\Admin\Desktop\focus', extension=".png", overwrite=True)

sequence = MDASequence(
    axis_order = "tpgcz",
    stage_positions = [(1200, 1214, z)],
    channels = [{'group': 'LED_light', 'config': 'on'}],
    z_plan = {'above': range, 'below': range, 'step': step_size}
)

with mda_listeners_connected(writer):
    core.mda.run(sequence)
    
core.snapImage()
im = core.getImage()

core.setConfig('LED_light', 'off')
# Out:
# 2024-08-20 10:34:44,511 - pymmcore-plus - INFO - (_runner.py:321) MDA Started: stage_positions=(Position(x=1200.0, y=1214.0, z=-928.0, name=None, sequence=None),) channels=(Channel(config='on', group='LED_light', exposure=None, do_stack=True, z_offset=0.0, acquire_every=1, camera=None),) z_plan=ZAboveBelow(go_up=True, above=20.0, below=20.0, step=2.0)
# 2024-08-20 10:34:44,515 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 0}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-948.0
# 2024-08-20 10:34:45,109 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 1}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-946.0
# 2024-08-20 10:34:45,702 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 2}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-944.0
# 2024-08-20 10:34:46,274 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 3}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-942.0
# 2024-08-20 10:34:46,852 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 4}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-940.0
# 2024-08-20 10:34:47,448 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 5}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-938.0
# 2024-08-20 10:34:48,046 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 6}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-936.0
# 2024-08-20 10:34:48,625 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 7}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-934.0
# 2024-08-20 10:34:49,179 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 8}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-932.0
# 2024-08-20 10:34:49,745 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 9}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-930.0
# 2024-08-20 10:34:50,342 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 10}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-928.0
# 2024-08-20 10:34:50,905 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 11}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-926.0
# 2024-08-20 10:34:51,503 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 12}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-924.0
# 2024-08-20 10:34:52,114 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 13}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-922.0
# 2024-08-20 10:34:52,714 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 14}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-920.0
# 2024-08-20 10:34:53,342 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 15}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-918.0
# 2024-08-20 10:34:53,965 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 16}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-916.0
# 2024-08-20 10:34:54,554 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 17}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-914.0
# 2024-08-20 10:34:55,180 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 18}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-912.0
# 2024-08-20 10:34:55,821 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 19}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-910.0
# 2024-08-20 10:34:56,417 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 20}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-908.0
# 2024-08-20 10:34:57,020 - pymmcore-plus - INFO - (_runner.py:408) MDA Finished: stage_positions=(Position(x=1200.0, y=1214.0, z=-928.0, name=None, sequence=None),) channels=(Channel(config='on', group='LED_light', exposure=None, do_stack=True, z_offset=0.0, acquire_every=1, camera=None),) z_plan=ZAboveBelow(go_up=True, above=20.0, below=20.0, step=2.0)

# %%
focus_images = glob.glob(r'C:\Users\Admin\Desktop\focus\*.png')
len(focus_images)
# Out:
# 21

# %%
focus_scores = []
for f in focus_images:
    im = cv2.imread(rf'{f}')
    im_filtered = cv2.medianBlur(im, ksize=3)
    laplacian = cv2.Laplacian(im_filtered, ddepth=cv2.CV_64F, ksize=3)
    focus_score = laplacian.var()
    focus_scores.append(focus_score)
focus_scores
# Out:
# [6.047063823789358,
#  6.166294097237234,
#  6.292264927548632,
#  6.411439888586756,
#  6.522073729151813,
#  6.636154155945405,
#  6.736683839178603,
#  6.791141485845171,
#  6.8650217047248026,
#  6.92770576410724,
#  6.981914514442906,
#  7.0282449655801775,
#  7.1156797307826665,
#  7.2270393278801635,
#  7.3918857499144535,
#  7.538502675980939,
#  7.628653501092715,
#  7.656436896590634,
#  7.554666502343025,
#  7.296610823209931,
#  6.899375895873807]

# %%
# define x and y for fitting
y = focus_scores
x = np.linspace(z-range, z+range, len(y))

# define gauss fit function
mean = sum(x * y) / sum(y)
sigma = np.sqrt(sum(y * (x - mean)**2) / sum(y))
def gauss(x, a, x0, sigma):
    return a * np.exp(-(x - x0)**2 / (2 * sigma**2))

popt, pcov = curve_fit(gauss, x, y, p0=[np.max(y), mean, sigma])

# calculate maximum focus score of fit function
x_fine = np.linspace(z-range, z+range, 100)
y_max = np.max(gauss(x_fine,*popt))
pos = np.where(y_max == gauss(x_fine,*popt))
x_max = x_fine[pos]
y_max_data = np.max(focus_scores)
x_max_data = x[np.where(focus_scores == y_max_data)]

# plot focus scores, fit function and maximum
fig, ax = plt.subplots(figsize=(4, 3))
plt.plot(x, y, label='data')
plt.plot(x_fine, gauss(x_fine, *popt), label='fit')
plt.plot(x_max, y_max, marker='X', label='max_fit', ms=10)
plt.plot(x_max_data, y_max_data, marker='X', label='max_data', ms=10)
plt.xlabel('z position (mu)')
plt.ylabel('focus score')
plt.legend()
plt.show()

# set optimal z position 
core.setPosition(float(x_max[0]))

print(float(x_max[0]), float(x_max_data[0]))
# Out:
# -913.2525252525253 -914.0

# %%
# compare maximum focus score of data vs. gaussian fit function
core.setConfig('LED_light', 'on')
time.sleep(1)

core.setPosition(float(x_max[0]))
core.snapImage()
im_fit = core.getImage()

core.setPosition(float(x_max_data[0]))
core.snapImage()
im_data = core.getImage()

time.sleep(1)
core.setConfig('LED_light', 'off')

fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
ax[0].imshow(im_fit, cmap='gray')
ax[0].set_title(f'fit, value={np.round(x_max[0], 1)}', fontsize=20)
ax[1].imshow(im_data, cmap='gray')
ax[1].set_title(f'data, value={np.round(x_max_data[0], 1)}', fontsize=20)
# Out:
# Text(0.5, 1.0, 'data, value=-914.0')

# %%
# remove focus images 
for file in focus_images:
    os.remove(file)
