# %% [markdown]
# # 3. software autofocus

# %%
import os
import time
from useq import MDAEvent, MDASequence, Position
from pymmcore_plus.mda import mda_listeners_connected
from pymmcore_plus.mda.handlers import ImageSequenceWriter
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import numpy as np
from scipy.optimize import curve_fit
import glob
import pandas as pd
import m2stitch
from os import path

# set micro manager directory
mm_dir = 'D:\ProgramFiles\Micro-Manager-2.0'

# load micro manager system configuration
from pymmcore_plus import CMMCorePlus, Device, DeviceAdapter, ConfigGroup
core = CMMCorePlus()
#core_plus.setDeviceAdapterSearchPaths([mm_dir])
core.loadSystemConfiguration(os.path.join(mm_dir, 'MMConfig_Edge42_SOLA_ASIStage_PixelSize.cfg'))

# %%
# set field of view size
f = 1192.8

# %%
# acquire z-stack

z = -928
range = 20
step_size = 2

writer = ImageSequenceWriter(r'C:\Users\Admin\Desktop\focus', extension=".png", overwrite=True)

sequence = MDASequence(
    axis_order = "tpgcz",
    stage_positions = [(1200, 1214, z)],
    channels = [{'group': 'LED_light', 'config': 'on'}],
    z_plan = {'above': range, 'below': range, 'step': step_size}
)

with mda_listeners_connected(writer):
    core.mda.run(sequence)
    
core.snapImage()
im = core.getImage()

core.setConfig('LED_light', 'off')
# Out:
# 2024-08-29 19:39:50,010 - pymmcore-plus - INFO - (_runner.py:321) MDA Started: stage_positions=(Position(x=1200.0, y=1214.0, z=-928.0, name=None, sequence=None),) channels=(Channel(config='on', group='LED_light', exposure=None, do_stack=True, z_offset=0.0, acquire_every=1, camera=None),) z_plan=ZAboveBelow(go_up=True, above=20.0, below=20.0, step=2.0)
# 2024-08-29 19:39:50,012 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 0}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-948.0
# 2024-08-29 19:39:51,004 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 1}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-946.0
# 2024-08-29 19:39:51,614 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 2}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-944.0
# 2024-08-29 19:39:52,206 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 3}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-942.0
# 2024-08-29 19:39:52,817 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 4}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-940.0
# 2024-08-29 19:39:53,417 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 5}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-938.0
# 2024-08-29 19:39:54,034 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 6}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-936.0
# 2024-08-29 19:39:54,677 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 7}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-934.0
# 2024-08-29 19:39:55,298 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 8}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-932.0
# 2024-08-29 19:39:55,899 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 9}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-930.0
# 2024-08-29 19:39:56,522 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 10}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-928.0
# 2024-08-29 19:39:57,118 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 11}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-926.0
# 2024-08-29 19:39:57,714 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 12}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-924.0
# 2024-08-29 19:39:58,305 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 13}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-922.0
# 2024-08-29 19:39:58,947 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 14}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-920.0
# 2024-08-29 19:39:59,604 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 15}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-918.0
# 2024-08-29 19:40:00,241 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 16}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-916.0
# 2024-08-29 19:40:00,874 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 17}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-914.0
# 2024-08-29 19:40:01,513 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 18}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-912.0
# 2024-08-29 19:40:02,141 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 19}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-910.0
# 2024-08-29 19:40:02,823 - pymmcore-plus - INFO - (_runner.py:283) index=mappingproxy({'p': 0, 'c': 0, 'z': 20}) channel=Channel(config='on', group='LED_light') x_pos=1200.0 y_pos=1214.0 z_pos=-908.0
# 2024-08-29 19:40:03,464 - pymmcore-plus - INFO - (_runner.py:408) MDA Finished: stage_positions=(Position(x=1200.0, y=1214.0, z=-928.0, name=None, sequence=None),) channels=(Channel(config='on', group='LED_light', exposure=None, do_stack=True, z_offset=0.0, acquire_every=1, camera=None),) z_plan=ZAboveBelow(go_up=True, above=20.0, below=20.0, step=2.0)

# %%
focus_images = glob.glob(r'C:\Users\Admin\Desktop\focus\*.png')
len(focus_images)
# Out:
# 21

# %%
focus_scores = []
for f in focus_images:
    im = cv2.imread(rf'{f}')
    im_filtered = cv2.medianBlur(im, ksize=3)
    laplacian = cv2.Laplacian(im_filtered, ddepth=cv2.CV_64F, ksize=3)
    focus_score = laplacian.var()
    focus_scores.append(focus_score)
focus_scores
# Out:
# [6.041006086332345,
#  6.106012343308976,
#  6.229769704759331,
#  6.349050521587581,
#  6.445124624880502,
#  6.52630423590017,
#  6.606965062495456,
#  6.689194676940623,
#  6.717073438709813,
#  6.73684215539064,
#  6.8550634333674125,
#  6.835186003255103,
#  7.018297195229678,
#  7.054637908170399,
#  7.299431797835073,
#  7.301146501940397,
#  7.349997488472156,
#  7.281142226507228,
#  7.129153229086597,
#  6.83648585142467,
#  6.360799788115401]

# %%
# define x and y for fitting
y = focus_scores
x = np.linspace(z-range, z+range, len(y))

# define gauss fit function
mean = sum(x * y) / sum(y)
sigma = np.sqrt(sum(y * (x - mean)**2) / sum(y))
def gauss(x, a, x0, sigma):
    return a * np.exp(-(x - x0)**2 / (2 * sigma**2))

popt, pcov = curve_fit(gauss, x, y, p0=[np.max(y), mean, sigma])

# calculate maximum focus score of fit function
x_fine = np.linspace(z-range, z+range, 100)
y_max = np.max(gauss(x_fine,*popt))
pos = np.where(y_max == gauss(x_fine,*popt))
x_max = x_fine[pos]
y_max_data = np.max(focus_scores)
x_max_data = x[np.where(focus_scores == y_max_data)]

# plot focus scores, fit function and maximum
fig, ax = plt.subplots(figsize=(4, 3))
plt.plot(x, y, label='data')
plt.plot(x_fine, gauss(x_fine, *popt), label='fit')
plt.plot(x_max, y_max, marker='X', label='max_fit', ms=10)
plt.plot(x_max_data, y_max_data, marker='X', label='max_data', ms=10)
plt.xlabel('z position (mu)')
plt.ylabel('focus score')
plt.legend()
plt.show()

# set optimal z position 
core.setPosition(float(x_max[0]))

print(float(x_max[0]), float(x_max_data[0]))
# Out:
# -919.7171717171717 -916.0

# %%
# compare maximum focus score of data vs. gaussian fit function
core.setConfig('LED_light', 'on')
time.sleep(1)

core.setPosition(float(x_max[0]))
core.snapImage()
im_fit = core.getImage()

core.setPosition(float(x_max_data[0]))
core.snapImage()
im_data = core.getImage()

time.sleep(1)
core.setConfig('LED_light', 'off')

fig, ax = plt.subplots(ncols=2, figsize=(10, 5))
ax[0].imshow(im_fit, cmap='gray')
ax[0].set_title(f'fit, value={np.round(x_max[0], 1)}', fontsize=20)
ax[1].imshow(im_data, cmap='gray')
ax[1].set_title(f'data, value={np.round(x_max_data[0], 1)}', fontsize=20)
# Out:
# Text(0.5, 1.0, 'data, value=-916.0')

# %%
# remove focus images 
for file in focus_images:
    os.remove(file)
